# %%
# !pip install pytesseract

# %%
import pytesseract
import cv2
import matplotlib.pyplot as plt
from PIL import Image
from paddleocr import PaddleOCR

# %%
# !pip install langchain openai chromadb langchainhub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 2.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.1/448.1 kB 3.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.8/395.8 kB 2.9 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 4.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 6.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 7.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.4/473.4 kB 7.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.2/197.2 kB 9.9 MB/s eta 0:00:00
# ...

# %%
import openai

# %%
openai.api_key = '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'

# %%
words1 = " ".join(words)

# %%
words1
# Out:
# 'DINNER *S7VIDS* HAPPY HOUR Single Mimosas -4 INTHE EVERYDAY Orange,Strawberry,Mango WOOD 3-6PM Cranberry or Coconut) Double Mimosas -7 Mimosa Pitcher(6 glasses)-19 S2OFF Red Sangria-7 ALLDRAFT BEERS Sangria Pitcher4 glasses)-22 &HOUSE WINES Pitchers&Bottles Draft Beer Pitcher4 glasses)-24 not included DRAFT BEER WINE see chalkboard for rotating beers Dry Creek(House White-Chenin Blanc-9/30 Dust Bowl-Taco Truck Lager16oz-7,5 La Jolie Fleur-Rose-10/36 Pilsner Rotating16oz-8 li-Prosecco-10/36 Drake\'s 1500-Pale Ale16oz-8 Whitehaven-Sauvignon Blanc -11/40 Gilman West Coast IPA(16oz-8 Alfaro-Chardonnay- 12/44 Ghost Town Hazy IPA(12oz-7.5 The Whole Shebang(House Red)-Red Blend -9.5/32 Boont Amber(12oz-7.5 William Hill-Pinot Noir -11/40 Headlands Double IPA12oz-7.5 Black Cabra-Malbec-11/40 Sour Rotating12oz-7.5 Rabble-Zinfandel-12.5/46 Vina Robles -Cabernet Sauvignon -12.5/46 BOTTLES\'N\'CANS Non Alcoholic Beer Rotating12oz-7 Pabst Blue Ribbon12oz-Lager-5 BEVERAGES North Coast-Scrimshaw Pi
# ...

# %%
# Function to extract text from image file. Should be adjusted to accomodate pdf, word, and other document types

def extract_words(images):
    ocr = PaddleOCR(use_angle_cls=True, lang='en')
    result = ocr.ocr(images, cls=True)
    
    return result

# Following extraction of words from file, function to make list out of words from file.
def make_word_list(results):
    words = []
    for i in range(0,len(result),1):
        words.append(result[i][1][0])
    return words

# %%
# !pip install typing_extensions==4.7.1 --upgrade

# %%
# !pip install tensorflow-io-gcs-filesystem>=0.23.1

# %%
# !pip install protobuf==3.19.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 2.5 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# visualdl 2.5.3 requires protobuf>=3.20.0, but you have protobuf 3.19.1 which is incompatible.
# paddlepaddle 2.5.1 requires protobuf>=3.20.2; platform_system != "Windows", but you have protobuf 3.19.1 which is incompatible.
# googleapis-common-protos 1.58.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.19.1 which is incompatible.
# ...

# %%
# !pip install torch torchaudio --index-url https://download.pytorch.org/whl/rocm5.4.2
# Out:
# Looking in indexes: https://download.pytorch.org/whl/rocm5.4.2
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 5.9 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from typing_extensions import Annotated, deprecated
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 from typing_extensions import Annotated, deprecated
#
# ImportError: cannot import name 'deprecated' from 'typing_extensions' (/Users/pat/opt/anaconda3/lib/python3.9/site-packages/typing_extensions.py)

# %%
# !pip install typing-extensions --upgrade
# Out:
# ...
#   Using cached typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
# ...

# %%
# Splitting

from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 20, chunk_overlap = 0)
splits = text_splitter.split_documents(words1)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/langchain/pydantic_v1/__init__.py:15
#      14 try:
# ---> 15     from pydantic.v1 import *  # noqa: F403
#      16 except ImportError:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pydantic/__init__.py:3
#       1 import typing
# ----> 3 import pydantic_core
#       4 from pydantic_core.core_schema import (
#       5     FieldSerializationInfo,
#       6     SerializationInfo,
#    (...)
#       9     ValidatorFunctionWrapHandler,
#      10 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pydantic_core/__init__.py:29
#       6 from ._pydantic_core import (
#       7     ArgsKwargs,
#       8     MultiHostUrl,
#    (...)
#      27     validate_core_schema,
#      28 )
# ---> 29 from .core_schema import CoreConfig, CoreSchema, CoreSchemaType, ErrorType
# ...

# %%
# storing and vectorizing text

from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
vectorstore = Chroma.from_documents(documents=splits,embedding=OpenAIEmbeddings())
retriever = vectorstore.as_retriever()

# %%
# Tokenizing of document and question

from langchain import hub
rag_prompt = hub.pull("rlm/rag-prompt")

# %%
# Importing chat model from open AI
from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

# %%
# Creating retrival chain

from langchain.schema.runnable import RunnablePassthrough
rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()} 
    | rag_prompt 
    | llm 
)

# %%
# Generating response to question

question = question
rag_chain.invoke(question)

# %%
image = cv2.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 image = cv2.imread('menu.jpeg')
#
# AttributeError: module 'cv2' has no attribute 'imread'

# %%
import sys
print(sys.version)
# Out:
# 3.9.12 (main, Jun  1 2022, 06:34:44)
# [Clang 12.0.0 ]

# %%
# !pip install opencv-python
# !pip install opencv-contrib-python
# !pip install opencv-contrib-python-headless
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 7.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 MB 18.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 MB 7.4 MB/s eta 0:00:0000:0100:01
# ...

# %%
import cv2

# %%
image = Image.open('1.jpeg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 image = Image.open('1.jpeg')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/PIL/Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '1.jpeg'

# %%
string = pytesseract.image_to_string(image)

print(string)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pytesseract/pytesseract.py:255, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     254 try:
# --> 255     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     256 except OSError as e:
#
# File ~/opt/anaconda3/lib/python3.9/subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
# ...

# %%
import tesseract
# Out:
# Traceback (most recent call last):
#
#   File ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3505 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[23], line 1
#     import tesseract
#
#   File ~/opt/anaconda3/lib/python3.9/site-packages/tesseract/__init__.py:34
#     print 'Creating user config file: {}'.format(_config_file_usr)
#           ^
# SyntaxError: invalid syntax

# %%
pytesseract.pytesseract.tesseract_cmd = r'//opt/homebrew/bin/tesseract'

# %%
y = pytesseract.image_to_string('3.jpg')

# %%
type(y)
# Out:
# str

# %%
print(y)
# Out:
# See back 9
# to win $1000 5
#
# D/PROV/Dc 00787421941
# E OIL 4 git
# Appt 3 oft o
#
# Hd fs FRM 4 _Sazeiestae
# BAGELS 1013
# GV SLIDERS
#
# ACCESSORY 61.
# CHEEZE IT
# WAS 4.54 YOU SAV
#
# R, Goaao 00
#
# RUFFLES 10020942 F
#
# GV HNY GRHS OaTeTgOTEES Fi
# SUBTOTAL
#
# TAX 1 = 7,000
# TOTAL
# SH TEND,
# ie
#
# wii
#
# il
#
# Ey
#
# VTA NGI O-207
#
# Hi
# 2
# 2)
# 3
# 0
# 4
# 2:
# 2.
# 15
# 9
# 4
# 4
# 0,
# 6.
#
# i
#
# i)
#
# Scan vith \Galrart arr dene receipts

# %%
pry
# Out:
# 'Give us feedback @ survey.walmart .com\nThank you! ID #:7PB6SJWCFZ2\n\nWalmart >\\<\n\n949-498-6669 Mor : Mae\n951 _AVENIDA PICO\nSAN CLEMENTE CA 92673\nST# 02527 OP# 009045 TE# 45 TR¥ 06193\nGV OATMEAL 007874243408 F 1.76 0\nOT 2002 TUM 081236803115 6.74 X\nM ATHLETICS 019104567781 24.97 X\nDEXAS 15X20 008429710921 12.97 X\n\nTAX 1 7.750% 3.46\nCHANGE DUE 0.\nDEBIT PAY FROM PRIMARY\n49.90 TOTAL PURCHASE\nUs DEBIT xxx naxx trex 9689 I 0\n\nREF # 029200639128\nNETWORK ID. 0056 APPR CODE 461500\n\n1004\na 11:30:42\n\nwii ii\n\n+\nPitroduciny Walmart+\nJoin today at walmarL.com/plus\n\n‘ices You Trust. Every Day.\nbw Pe eraa en” Tt:80:46\n\n'

# %%
# !pip install keras-ocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 3.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.3/278.3 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.7 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 6.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 4.5 MB/s eta 0:00:00
# ...

# %%
import keras_ocr

# %%
images = [
    keras_ocr.tools.read(pics) for pics in [
        'menu.jpeg',
        '0.jpg',
    ]
]

# %%
# !pip install opencv-python==4.5.5.64
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.9/29.9 MB 13.6 MB/s eta 0:00:0000:010:01m
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.8.1.78
#     Uninstalling opencv-python-4.8.1.78:
#       Successfully uninstalled opencv-python-4.8.1.78
# ...

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /Users/pat/.keras-ocr/craft_mlt_25k.h5
# Looking for /Users/pat/.keras-ocr/crnn_kurapan.h5

# %%
read = keras_ocr.tools.read('1.jpg')
#groups = pipeline.recognize([read])

# %%
prediction_group = pipeline.recognize([read])
# Out:
# 2023-10-09 02:21:41.311418: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# ...
# 6/6 [==============================] - 6s 903ms/step

# %%
prediction_group
# Out:
# [[('joets',
#    array([[374.58972, 133.51358],
#           [495.87616, 131.70334],
#           [496.37128, 164.87506],
#           [375.08484, 166.6853 ]], dtype=float32)),
#   ('trader',
#    array([[189.16936, 140.40955],
#           [359.6622 , 134.40628],
#           [360.83533, 167.72412],
#           [190.3425 , 173.72739]], dtype=float32)),
#   ('greenville',
#    array([[262.50012, 204.7544 ],
#           [359.76636, 201.34155],
#           [360.48816, 221.91272],
#           [263.22192, 225.32556]], dtype=float32)),
#   ('ave',
#    array([[366., 202.],
#           [397., 202.],
#           [397., 220.],
#           [366., 220.]], dtype=float32)),
#   ('2001',
#    array([[217., 207.],
#           [256., 207.],
#           [256., 227.],
#           [217., 227.]], dtype=float32)),
#   ('75206',
#    array([[338.34805, 222.61325],
#           [387.79007, 220.01105],
#           [388.80942, 239.37845],
#           [339.3674 , 241.98065]], dtype=float32)),
#   ('tx',
# ...

# %%
import pytesseract

# %%
# !pip install easyocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 2.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 MB 7.5 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.7/270.7 kB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.6 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from easyocr import Reader

# %%
reader = Reader(['en'])

# %%
reader.readtext('1.jpg')
# Out:
# [([[185, 124], [502, 124], [502, 178], [185, 178]],
#   "TRADER JOE'$",
#   0.5242111432567371),
#  ([[216, 198], [400, 198], [400, 230], [216, 230]],
#   '2001 Greenvi Ile Ave',
#   0.4431841295520629),
#  ([[224, 222], [288, 222], [288, 248], [224, 248]],
#   'Da| Ias',
#   0.4835114396530134),
#  ([[301, 223], [325, 223], [325, 243], [301, 243]], 'TX', 0.9564736671558363),
#  ([[336, 218], [390, 218], [390, 244], [336, 244]],
#   '75206',
#   0.9999539916061304),
#  ([[180, 244], [280, 244], [280, 270], [180, 270]],
#   'Store #403',
#   0.9318789609328157),
#  ([[300, 236], [438, 236], [438, 264], [300, 264]],
#   '(469) 334-0614',
#   0.6316429800026406),
#  ([[181, 277], [441, 277], [441, 315], [181, 315]],
#   'OPEN 8:OOAM TO 9:OOPM DAILY',
#   0.35966256812638997),
#  ([[120, 326], [348, 326], [348, 358], [120, 358]],
#   'R-CARROTS   SHREDDED 10 0Z',
#   0.6258839902817057),
#  ([[120, 344], [352, 344], [352, 392], [120, 392]],
#   'ERCUGDESEERUSFESTAU SAEE',
# ...

# %%
# !pip install "paddleocr>=2.0.1"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.7/465.7 kB 3.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.5/881.5 kB 3.5 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 4.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 6.4 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.4/148.4 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 6.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 MB 17.3 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.9/38.9 MB 11.4 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !pip install PyMuPDF
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 3.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.3/29.3 MB 8.2 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !pip install "paddleocr>=2.0.1"
# Out:
# ...
#   Using cached paddleocr-2.7.0.3-py3-none-any.whl (465 kB)
# ...
#   Using cached visualdl-2.5.3-py3-none-any.whl (6.3 MB)
# ...
#   Using cached premailer-3.10.0-py2.py3-none-any.whl (19 kB)
# ...
#   Using cached attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# ...
#   Using cached PyMuPDF-1.20.2.tar.gz (90.4 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached fire-0.5.0-py2.py3-none-any.whl
# ...
#   Using cached opencv_contrib_python-4.6.0.66-cp37-abi3-macosx_11_0_arm64.whl (38.9 MB)
# ...
#   Using cached pdf2docx-0.5.6-py3-none-any.whl (148 kB)
# ...
#   Using cached Pillow-10.0.1-cp39-cp39-macosx_11_0_arm64.whl (3.3 MB)
# ...
#   Using cached cssutils-2.7.1-py3-none-any.whl (399 kB)
# ...
#   Using cached bce_python_sdk-0.8.90-py3-none-any.whl (235 kB)
# ...
#   Using cached flask_babel-4.0.0-py3-none-any.whl (9.6 kB)
# ...
#   Using cached Babel-2.13.0-py3-none-any.whl (10.1 MB)
# ...
#   Using cached pycryptodome-3.19.0-cp35-abi3-macosx_10_9_universal2.whl (2.4 MB)
# ...
#   error: subprocess-exited-with-error
#
# ...

# %%
python3 setup.py bdist_wheel
# !pip3 install dist/paddleocr-2.0.1-py3-none-any.whl
# Out:
#   Cell In[40], line 1
#     python3 setup.py bdist_wheel
#             ^
# SyntaxError: invalid syntax

# %%
# !pip install cmake
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 27.6 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !pip install '/Users/pat/Downloads/PyMuPDF-1.20.2-cp311-cp311-win_amd64.whl'
# Out:
# ERROR: PyMuPDF-1.20.2-cp311-cp311-win_amd64.whl is not a supported wheel on this platform.

# %%
# !pip install --upgrade PyMuPDF==1.21.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 4.3 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: PyMuPDF
#     Found existing installation: PyMuPDF 1.23.4
#     Uninstalling PyMuPDF-1.23.4:
#       Successfully uninstalled PyMuPDF-1.23.4
# ...

# %%
# !pip install "paddleocr>=2.0.1" --upgrade PyMuPDF==1.21.1
# Out:
# ...
#   Using cached paddleocr-2.7.0.3-py3-none-any.whl (465 kB)
# ...
#   Using cached premailer-3.10.0-py2.py3-none-any.whl (19 kB)
# ...
#   Using cached visualdl-2.5.3-py3-none-any.whl (6.3 MB)
# ...
#   Using cached Pillow-10.0.1-cp39-cp39-macosx_11_0_arm64.whl (3.3 MB)
# ...
#   Using cached pdf2docx-0.5.6-py3-none-any.whl (148 kB)
# ...
#   Using cached attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# ...
#   Using cached opencv_contrib_python-4.6.0.66-cp37-abi3-macosx_11_0_arm64.whl (38.9 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 466.1/466.1 kB 1.7 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.4/463.4 kB 2.4 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.1/74.1 MB 8.2 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.9/445.9 kB 9.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.6/440.6 kB 10.3 MB/s eta 0:00:0000:01
# ...

# %%
# !pip install paddle
# Out:
# ...
#   Using cached paddle-1.0.2.tar.gz (579 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for paddle: filename=paddle-1.0.2-py3-none-any.whl size=33366 sha256=90d3a9b5d31812a67477f1f47670ce63377dd44409b6af694a031318bfdeef55
#   Stored in directory: /Users/pat/Library/Caches/pip/wheels/a0/6a/49/78d1901675c5267c505866cdc8eee540a7e4bad28b79d974d8
# Successfully built paddle
# ...

# %%
from paddleocr import PaddleOCR

# %%
ocr = PaddleOCR(use_angle_cls=True, lang='en')
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to /Users/pat/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer/en_PP-OCRv3_det_infer.tar
# 100%|██████████| 4.00M/4.00M [00:18<00:00, 220kiB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_rec_infer.tar to /Users/pat/.paddleocr/whl/rec/en/en_PP-OCRv3_rec_infer/en_PP-OCRv3_rec_infer.tar
# 100%|██████████| 9.96M/9.96M [00:19<00:00, 523kiB/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to /Users/pat/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer/ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████| 2.19M/2.19M [00:09<00:00, 221kiB/s]
# ...

# %%
images = ['menu.jpeg','2.jpg']

# %%
from paddleocr import PaddleOCR

# %%
def extract_words(images):
    ocr = PaddleOCR(use_angle_cls=True, lang='en')
    result = ocr.ocr(images, cls=True)
    
    return result


def make_word_list(results):
    words = []
    for i in range(0,len(result),1):
        words.append(result[i][1][0])
    return words

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
result = ocr.ocr(images, cls=True)
# Out:
# [2023/10/10 05:55:43] ppocr ERROR: When input a list of images, det must be false
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 result = ocr.ocr(images, cls=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/paddleocr/paddleocr.py:515, in PaddleOCR.ocr(self, img, det, rec, cls)
#     513 if isinstance(img, list) and det == True:
#     514     logger.error('When input a list of images, det must be false')
# --> 515     exit(0)
#     516 if cls == True and self.use_angle_cls == False:
#     517     logger.warning(
#     518         'Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process'
#     519     )
#
# NameError: name 'exit' is not defined

# %%
result
# Out:
# [('', 0.0), ('', 0.0)]

# %%
result[-1][1][0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 result[-1][1][0]
#
# TypeError: 'float' object is not subscriptable

# %%
len(result)
# Out:
# 73

# %%
words = []
for i in range(0,len(result),1):
    words.append(result[i][1][0])
words
# Out:
# ['DINNER',
#  '*S7VIDS*',
#  'HAPPY HOUR',
#  'Single Mimosas -4',
#  'INTHE',
#  'EVERYDAY',
#  'Orange,Strawberry,Mango',
#  'WOOD',
#  '3-6PM',
#  'Cranberry or Coconut)',
#  'Double Mimosas -7',
#  'Mimosa Pitcher(6 glasses)-19',
#  'S2OFF',
#  'Red Sangria-7',
#  'ALLDRAFT BEERS',
#  'Sangria Pitcher4 glasses)-22',
#  '&HOUSE WINES',
#  'Pitchers&Bottles',
#  'Draft Beer Pitcher4 glasses)-24',
#  'not included',
#  'DRAFT BEER',
#  'WINE',
#  'see chalkboard for rotating beers',
#  'Dry Creek(House White-Chenin Blanc-9/30',
#  'Dust Bowl-Taco Truck Lager16oz-7,5',
#  'La Jolie Fleur-Rose-10/36',
#  'Pilsner Rotating16oz-8',
#  'li-Prosecco-10/36',
#  "Drake's 1500-Pale Ale16oz-8",
#  'Whitehaven-Sauvignon Blanc -11/40',
#  'Gilman West Coast IPA(16oz-8',
#  'Alfaro-Chardonnay- 12/44',
#  'Ghost Town Hazy IPA(12oz-7.5',
#  'The Whole Shebang(House Red)-Red Blend -9.5/32',
#  'Boont Amber(12oz-7.5',
#  'William Hill-Pinot Noir -11/40',
#  'Headlands Double IPA12oz-7.5',
# ...

# %%
def make_word_list(results):
    words = []
    for i in range(0,len(result),1):
        words.append(result[i][1][0])
    return words

# %%
# !pip install setuptools==59.5.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 kB 1.9 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 68.2.2
#     Uninstalling setuptools-68.2.2:
#       Successfully uninstalled setuptools-68.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.10.0 requires tensorflow-io-gcs-filesystem>=0.23.1, which is not installed.
# conda-repo-cli 1.0.41 requires requests_mock, which is not installed.
# tensorflow 2.10.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# tensorboard 2.10.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.2 which is incompatible.
# ...

# %%
# !pip install --upgrade setuptools
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.9/807.9 kB 1.2 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.6.3
#     Uninstalling setuptools-65.6.3:
#       Successfully uninstalled setuptools-65.6.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.10.0 requires tensorflow-io-gcs-filesystem>=0.23.1, which is not installed.
# conda-repo-cli 1.0.41 requires requests_mock, which is not installed.
# tensorflow 2.10.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# tensorboard 2.10.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.2 which is incompatible.
# ...

# %%
import numpy
numpy.__version__
# Out:
# '1.21.5'
